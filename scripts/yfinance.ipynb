# %%
from pathlib import Path
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={"figure.dpi":100, 'savefig.dpi':100, 'figure.figsize':(6,6)})

# %%
data = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")
data
# Out:
# [*********************100%***********************]  2 of 2 completed
#             Adj Close                  Close                   High  \
#                  AAPL         SPY       AAPL         SPY       AAPL
# Date
# 2017-01-03  27.257641  205.509125  29.037500  225.240005  29.082500
# 2017-01-04  27.227133  206.731705  29.004999  226.580002  29.127501
# 2017-01-05  27.365595  206.567474  29.152500  226.399994  29.215000
# 2017-01-06  27.670670  207.306534  29.477501  227.210007  29.540001
# 2017-01-09  27.924126  206.622223  29.747499  226.460007  29.857500
# ...               ...         ...        ...         ...        ...
# 2017-04-24  33.855042  217.335449  35.910000  237.169998  35.987499
# 2017-04-25  34.064812  218.600052  36.132500  238.550003  36.224998
# 2017-04-26  33.864471  218.462555  35.919998  238.399994  36.150002
# 2017-04-27  33.890388  218.645844  35.947498  238.600006  36.040001
# 2017-04-28  33.857391  218.169327  35.912498  238.080002  36.075001
#
# ...

# %%
# stocks_yf = df_stocks.query('cutoff_date == "2011-04-11"').codneg.to_list()
stocks_yf = [
    'CRUZ3', 'BRPR3', 'PTBL3', 'EQTL3', 'LIGT3', 'TOTS3', 'UGPA4', 'AUTM3', 'CIEL3',
    'VALE5', 'BRAP4', 'SBSP3', 'LAME4', 'WHRL4', 'CMIG4', 'ECOR3', 'CSMG3', 'GETI4',
    'CCIM3', 'BRKM5', 'RAPT4', 'SHUL4', 'ENGI4', 'CPFE3', 'HBOR3', 'VLID3', 'TRPL4',
    'ETER3', 'EVEN3', 'EUCA4'
]

# %%
stocks_yf = '.SA '.join(stocks_yf)
stocks_yf
# Out:
# 'CRUZ3.SA BRPR3.SA PTBL3.SA EQTL3.SA LIGT3.SA TOTS3.SA UGPA4.SA AUTM3.SA CIEL3.SA VALE5.SA BRAP4.SA SBSP3.SA LAME4.SA WHRL4.SA CMIG4.SA ECOR3.SA CSMG3.SA GETI4.SA CCIM3.SA BRKM5.SA RAPT4.SA SHUL4.SA ENGI4.SA CPFE3.SA HBOR3.SA VLID3.SA TRPL4.SA ETER3.SA EVEN3.SA EUCA4'

# %%
data = yf.download(stocks_yf, start="2011-04-11", end="2012-04-09")
data
# Out:
# [*********************100%***********************]  30 of 30 completed
#
# 7 Failed downloads:
# - AUTM3.SA: Data doesn't exist for startDate = 1302490800, endDate = 1333940400
# - GETI4.SA: No data found for this date range, symbol may be delisted
# - CRUZ3.SA: No data found for this date range, symbol may be delisted
# - EUCA4: No data found, symbol may be delisted
# - CCIM3.SA: No data found, symbol may be delisted
# - LAME4.SA: No data found, symbol may be delisted
# - UGPA4.SA: No data found for this date range, symbol may be delisted
#            Adj Close                                                     \
#             AUTM3.SA   BRAP4.SA   BRKM5.SA  BRPR3.SA CCIM3.SA  CIEL3.SA
# Date
# 2011-04-11       NaN  17.127106  11.809229  8.581649      NaN  4.456355
# 2011-04-12       NaN  16.682455  11.574089  8.483572      NaN  4.456355
# 2011-04-13       NaN  16.456161  11.621115  8.385496      NaN  4.475958
# ...

# %%
df_yf = yf.download('CIEL3.SA', start="2010-01-01", end="2022-06-01")
df_yf
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2010-01-04  7.695963  7.937089  7.635681  7.937089   4.936294   7856713
# 2010-01-05  7.911972  7.962207  7.756244  7.881831   4.901927   4355949
# 2010-01-06  7.836620  7.911972  7.786385  7.861737   4.889431  10207675
# 2010-01-07  7.796432  8.148075  7.786385  8.047606   5.005028  17911904
# 2010-01-08  8.067700  8.213381  7.937089  7.947136   4.942544   8385032
# ...              ...       ...       ...       ...        ...       ...
# 2022-05-25  3.640000  3.700000  3.590000  3.630000   3.630000  36698500
# 2022-05-26  3.670000  4.080000  3.670000  4.040000   4.040000  66549900
# 2022-05-27  4.010000  4.050000  3.940000  3.990000   3.990000  15828400
# 2022-05-30  4.000000  4.040000  3.890000  3.930000   3.930000  11660800
# 2022-05-31  3.950000  3.980000  3.910000  3.950000   3.950000  16651700
#
# [3078 rows x 6 columns]

# %%
PROCESSED_PATH = Path("/mnt/aq_disk/data/HistoricalQuotations/processed/")
path = PROCESSED_PATH / "base_adj.feather"
df_b3 = pd.read_feather(path)
df_b3
# Out:
#              datneg   codneg        nomres        codisi especi codbdi tpmerc  \
# 0        2022-02-03   5GTK11  INVESTO 5GTK  BR5GTKCTF000     CI     14     10
# 1        2022-02-04   5GTK11  INVESTO 5GTK  BR5GTKCTF000     CI     14     10
# 2        2022-02-07   5GTK11  INVESTO 5GTK  BR5GTKCTF000     CI     14     10
# 3        2022-02-08   5GTK11  INVESTO 5GTK  BR5GTKCTF000     CI     14     10
# 4        2022-02-09   5GTK11  INVESTO 5GTK  BR5GTKCTF000     CI     14     10
# ...             ...      ...           ...           ...    ...    ...    ...
# 10907282 2000-11-30  ZIVI4FF          ZIVI  BRZIVIACNPR1   PN *     96     20
# 10907283 2000-12-04  ZIVI4FF          ZIVI  BRZIVIACNPR1   PN *     96     20
# 10907284 2000-12-06  ZIVI4FF          ZIVI  BRZIVIACNPR1   PN *     96     20
# 10907285 2013-12-18   ZNTE6L  FERR ZANETTE  BRZNTEACNPB8    PNB     52     17
# 10907286 2012-12-13   ZNTE7L  FERR ZANETTE  BRZNTEACNPC6   PNC*     52     17
#
# ...

# %%
df = df_b3.query('codneg == "CIEL3" and datneg > "2010-01-01"').copy()
# df.set_index('datneg', inplace=True)
df
# Out:
#             datneg codneg nomres        codisi      especi codbdi tpmerc  \
# 2519853 2010-01-04  CIEL3  CIELO  BRCIELACNOR3  ON      NM      2     10
# 2519854 2010-01-05  CIEL3  CIELO  BRCIELACNOR3  ON      NM      2     10
# 2519855 2010-01-06  CIEL3  CIELO  BRCIELACNOR3  ON      NM      2     10
# 2519856 2010-01-07  CIEL3  CIELO  BRCIELACNOR3  ON      NM      2     10
# 2519857 2010-01-08  CIEL3  CIELO  BRCIELACNOR3  ON      NM      2     10
# ...            ...    ...    ...           ...         ...    ...    ...
# 2522938 2022-05-31  CIEL3  CIELO  BRCIELACNOR3  ON      NM      2     10
# 2522939 2022-06-01  CIEL3  CIELO  BRCIELACNOR3  ON      NM      2     10
# 2522940 2022-06-02  CIEL3  CIELO  BRCIELACNOR3  ON      NM      2     10
# 2522941 2022-06-03  CIEL3  CIELO  BRCIELACNOR3  ON      NM      2     10
# 2522942 2022-06-06  CIEL3  CIELO  BRCIELACNOR3  ON      NM      2     10
#
#            preabe    premax    premin  ...    preofv  preexe  totneg  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(rc={"figure.dpi":100, 'savefig.dpi':100, 'figure.figsize':(6,6)})

sns.lineplot(x="Date", y="Adj Close", data=df_yf)
sns.lineplot(x="datneg", y="preult", data=df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Adj Close'>

# %%
df_yf = yf.download('MGLU3.SA', start="2010-01-01", end="2022-06-01")
df_yf
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2011-05-02  0.503125  0.518750  0.503125  0.514062   0.463173  280003200
# 2011-05-03  0.515625  0.521562  0.506250  0.509375   0.458950   33670400
# 2011-05-04  0.510000  0.515000  0.510000  0.515000   0.464018   39203200
# 2011-05-05  0.512812  0.512812  0.510000  0.511875   0.461202   35097600
# 2011-05-06  0.510937  0.511875  0.500000  0.508125   0.457824   38672000
# ...              ...       ...       ...       ...        ...        ...
# 2022-05-25  3.700000  3.800000  3.640000  3.710000   3.710000  131838700
# 2022-05-26  3.720000  4.120000  3.720000  4.070000   4.070000  165741100
# 2022-05-27  4.080000  4.140000  3.920000  4.000000   4.000000   77138600
# 2022-05-30  4.030000  4.110000  3.780000  3.840000   3.840000   68432000
# 2022-05-31  3.880000  3.880000  3.700000  3.720000   3.720000  101983700
#
# ...

# %%
df = df_b3.query('codneg == "MGLU3" and datneg > "2010-01-01"').copy()
# df.set_index('datneg', inplace=True)
df
# Out:
#             datneg codneg       nomres        codisi      especi codbdi  \
# 6307835 2011-05-02  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
# 6307836 2011-05-03  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
# 6307837 2011-05-04  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
# 6307838 2011-05-05  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
# 6307839 2011-05-06  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
# ...            ...    ...          ...           ...         ...    ...
# 6310578 2022-05-31  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
# 6310579 2022-06-01  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
# 6310580 2022-06-02  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
# 6310581 2022-06-03  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
# 6310582 2022-06-06  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
#
#         tpmerc    preabe    premax    premin  ...    preofv  preexe  totneg  \
# ...

# %%
sns.lineplot(x="Date", y="Adj Close", data=df_yf)
sns.lineplot(x="datneg", y="preult", data=df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Adj Close'>

# %%
df1 = yf.download('BRKM3.SA', start="2010-01-01", end="2022-06-07")
df2 = df_b3.query('codneg == "BRKM3" and datneg > "2010-01-01"').copy()
sns.lineplot(x="Date", y="Adj Close", data=df1)
sns.lineplot(x="datneg", y="preult", data=df2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# <AxesSubplot:xlabel='Date', ylabel='Adj Close'>

# %%
df2['change'] = df2.premed / df2.premed.shift(1)
df2
# Out:
#             datneg codneg   nomres        codisi      especi codbdi tpmerc  \
# 1959822 2010-01-04  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1959823 2010-01-05  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1959824 2010-01-06  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1959825 2010-01-07  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1959826 2010-01-08  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# ...            ...    ...      ...           ...         ...    ...    ...
# 1962734 2022-05-31  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1962735 2022-06-01  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1962736 2022-06-02  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1962737 2022-06-03  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1962738 2022-06-06  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
#
# ...

# %%
df2.sort_values(by='change')
# Out:
#             datneg codneg   nomres        codisi      especi codbdi tpmerc  \
# 1962184 2020-03-12  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1962189 2020-03-19  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1961020 2015-03-11  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1961992 2019-06-04  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1962191 2020-03-23  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# ...            ...    ...      ...           ...         ...    ...    ...
# 1961766 2018-06-15  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1962194 2020-03-26  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1962185 2020-03-13  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1961364 2016-08-30  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
# 1959822 2010-01-04  BRKM3  BRASKEM  BRBRKMACNOR1  ON      N1      2     10
#
# ...

# %%
df.query('datneg > "2020-10-08" and datneg < "2020-10-17"')
# Out:
#             datneg codneg       nomres        codisi      especi codbdi  \
# 6310174 2020-10-09  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
# 6310175 2020-10-13  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON      NM      2
# 6310176 2020-10-14  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON  EB  NM      2
# 6310177 2020-10-15  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON  EB  NM      2
# 6310178 2020-10-16  MGLU3  MAGAZ LUIZA  BRMGLUACNOR2  ON  EB  NM      2
#
#         tpmerc     preabe     premax     premin  ...  preexe  totneg  \
# 6310174     10  22.934463  24.494206  22.859596  ...     0.0   83295
# 6310175     10  24.838598  26.053950  24.831111  ...     0.0   89675
# 6310176     10  26.453244  27.201921  24.995820  ...     0.0   83711
# 6310177     10  24.975855  26.024003  24.955890  ...     0.0   96438
# 6310178     10  25.714550  26.004038  25.115608  ...     0.0   75241
#
#                quatot        voltot  dismes  datven  prazot  event2    ajuste  \
# ...
